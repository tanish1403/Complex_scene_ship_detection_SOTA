# %%
# !pip install wandb -q
import wandb
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wandb_tanish")

wandb.login(key = secret_value_0)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tanish-jain140301 (tanish1403) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python --version
# Out:
# Python 3.11.13

# %%
# !pip install torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118 -q
# !pip install mmcv-full==1.7.1 -f https://download.openmmlab.com/mmcv/dist/cu116/torch1.13.0/index.html -q
# !pip install mmdet==2.28.2 -q
# !pip install -U openmim -q
# !mim install "mmengine>=0.7.0" -q
# !pip install xmltodict -q  # For dataset conversion
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 387.0 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 94.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 47.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 28.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lit (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.5.2 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 27.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 50.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 7.2 MB/s eta 0:00:00
#   Building wheel for oss2 (setup.py) ... done
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Building wheel for crcmod (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# datasets 3.6.0 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.6.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# pytorch-lightning 2.5.2 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# jupyterlab-server 2.27.3 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.0.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# pymc 5.23.0 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.5.1 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# yfinance 0.2.63 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# dataproc-spark-connect 0.7.5 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# dataproc-spark-connect 0.7.5 requires tqdm>=4.67, but you have tqdm 4.65.2 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# pytensor 2.31.4 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 18.4 MB/s eta 0:00:00

# %%
# !mim install 'mmcv==2.0.1'
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv==2.0.1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.1-cp311-cp311-manylinux1_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (0.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (11.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (6.0.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.0.1) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.0.1) (3.7.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.0.1) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.0.1) (3.1.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv==2.0.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv==2.0.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv==2.0.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv==2.0.1) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv==2.0.1) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv==2.0.1) (2.4.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv==2.0.1) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (2.9.0.post0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmcv==2.0.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmcv==2.0.1) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->mmcv==2.0.1) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->mmcv==2.0.1) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.0.1) (2.19.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->mmcv==2.0.1) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.0.1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.0.1) (1.17.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.1

# %%
# !mim install 'mmcv-full'
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv-full
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv_full-1.7.2-cp311-cp311-manylinux1_x86_64.whl (70.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 MB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (11.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (6.0.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv-full) (4.11.0.86)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-full) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-full) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-full) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-full) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-full) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-full) (2.4.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv-full) (4.3.8)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmcv-full) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmcv-full) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->mmcv-full) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->mmcv-full) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->mmcv-full) (2024.2.0)
# Installing collected packages: mmcv-full
# Successfully installed mmcv-full-1.7.2

# %%
# Step 6: Prepare Dataset (SCCOS to DOTA format)
import os
import shutil
import random
import xmltodict
import tqdm
import math

dataset_path = "/kaggle/input/sccos-dataset/"
working_dir = "/kaggle/working/sccos_dota"
train_images_dir = os.path.join(working_dir, "train/images")
train_labels_dir = os.path.join(working_dir, "train/labels")
val_images_dir = os.path.join(working_dir, "val/images")
val_labels_dir = os.path.join(working_dir, "val/labels")
test_images_dir = os.path.join(working_dir, "test/images")
test_labels_dir = os.path.join(working_dir, "test/labels")

# %%
# Step 4: Clone and Install MMRotate 0.3.4
# !git clone https://github.com/zhangpeng2001/nirnet.git /kaggle/working/mmrotate
# %cd /kaggle/working/mmrotate
# !git checkout v0.3.4  # Ensure exact version
# !pip install -r requirements/build.txt -q
# !pip install -v -e . -q
# Out:
# Cloning into '/kaggle/working/mmrotate'...
# remote: Enumerating objects: 482, done.
# remote: Counting objects: 100% (482/482), done.
# remote: Compressing objects: 100% (333/333), done.
# remote: Total 482 (delta 143), reused 474 (delta 135), pack-reused 0 (from 0)
# Receiving objects: 100% (482/482), 11.52 MiB | 18.70 MiB/s, done.
# Resolving deltas: 100% (143/143), done.
# /kaggle/working/mmrotate
# Obtaining file:///kaggle/working/mmrotate
#   Preparing metadata (setup.py) ... done
# Collecting e2cnn (from mmrotate==0.3.4)
#   Downloading e2cnn-0.2.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (3.7.2)
# Requirement already satisfied: mmcv-full in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (1.7.2)
# Requirement already satisfied: mmdet<3.0.0,>=2.25.1 in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (2.28.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (1.26.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (2.0.10)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (1.17.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (3.1.10)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from mmrotate==0.3.4) (2.0.1+cu118)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmdet<3.0.0,>=2.25.1->mmrotate==0.3.4) (1.15.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from e2cnn->mmrotate==0.3.4) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmrotate==0.3.4) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->mmrotate==0.3.4) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->mmrotate==0.3.4) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->mmrotate==0.3.4) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->mmrotate==0.3.4) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->mmrotate==0.3.4) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->mmrotate==0.3.4) (2.4.1)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmcv-full->mmrotate==0.3.4) (2.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv-full->mmrotate==0.3.4) (6.0.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmcv-full->mmrotate==0.3.4) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv-full->mmrotate==0.3.4) (4.11.0.86)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->mmrotate==0.3.4) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch->mmrotate==0.3.4) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->mmrotate==0.3.4) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->mmrotate==0.3.4) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch->mmrotate==0.3.4) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch->mmrotate==0.3.4) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch->mmrotate==0.3.4) (15.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->mmrotate==0.3.4) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmrotate==0.3.4) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmrotate==0.3.4) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->mmrotate==0.3.4) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->mmrotate==0.3.4) (2024.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->e2cnn->mmrotate==0.3.4) (1.3.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv-full->mmrotate==0.3.4) (4.3.8)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->mmrotate==0.3.4) (2024.2.0)
# Downloading e2cnn-0.2.3-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.3/225.3 kB 13.5 MB/s eta 0:00:00
# Installing collected packages: e2cnn, mmrotate
#   Running setup.py develop for mmrotate
# Successfully installed e2cnn-0.2.3 mmrotate-0.3.4

# %%
# Step 5: Verify Installations
# !pip list | grep -E 'torch|mmcv|mmdet|mmengine|mmrotate'
# Out:
# mmcv                                  2.0.1
# mmcv-full                             1.7.2
# mmdet                                 2.28.2
# mmengine                              0.10.7
# mmrotate                              0.3.4               /kaggle/working/mmrotate
# pytorch-ignite                        0.5.2
# pytorch-lightning                     2.5.2
# torch                                 2.0.1+cu118
# torchao                               0.10.0
# torchaudio                            2.0.2+cu118
# torchdata                             0.11.0
# torchinfo                             1.8.0
# torchmetrics                          1.7.3
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.15.2+cu118

# %%
# %%writefile /kaggle/working/mmrotate/mmrotate/core/bbox/assigners/convex_assigner.py
import torch
from mmdet.core.bbox.assigners.assign_result import AssignResult
from mmdet.core.bbox.assigners.base_assigner import BaseAssigner

from ..builder import ROTATED_BBOX_ASSIGNERS


@ROTATED_BBOX_ASSIGNERS.register_module()
class ConvexAssigner(BaseAssigner):
    """Assign a corresponding gt bbox or background to each bbox. Each
    proposals will be assigned with `0` or a positive integer indicating the
    ground truth index.

    - 0: negative sample, no assigned gt
    - positive integer: positive sample, index (1-based) of assigned gt

    Args:
        scale (float): IoU threshold for positive bboxes.
        pos_num (float): find the nearest pos_num points to gt center in this
        level.
    """

    def __init__(self, scale=4, pos_num=3):
        self.scale = scale
        self.pos_num = pos_num

    def get_horizontal_bboxes(self, gt_rbboxes):
        """get_horizontal_bboxes from polygons.

        Args:
            gt_rbboxes (torch.Tensor): Groundtruth polygons, shape (k, 8).

        Returns:
            gt_rect_bboxes (torch.Tensor): The horizontal bboxes, shape (k, 4).
        """
        gt_xs, gt_ys = gt_rbboxes[:, 0::2], gt_rbboxes[:, 1::2]
        gt_xmin, _ = gt_xs.min(1)
        gt_ymin, _ = gt_ys.min(1)
        gt_xmax, _ = gt_xs.max(1)
        gt_ymax, _ = gt_ys.max(1)
        gt_rect_bboxes = torch.cat([
            gt_xmin[:, None], gt_ymin[:, None], gt_xmax[:, None], gt_ymax[:,
                                                                          None]
        ],
                                   dim=1)

        return gt_rect_bboxes

    def assign(self,
               points,
               gt_rbboxes,
               gt_rbboxes_ignore=None,
               gt_labels=None,
               overlaps=None):
        """Assign gt to bboxes.

        The assignment is done in following steps

        1. compute iou between all bbox (bbox of all pyramid levels) and gt
        2. compute center distance between all bbox and gt
        3. on each pyramid level, for each gt, select k bbox whose center
           are closest to the gt center, so we total select k*l bbox as
           candidates for each gt
        4. get corresponding iou for the these candidates, and compute the
           mean and std, set mean + std as the iou threshold
        5. select these candidates whose iou are greater than or equal to
           the threshold as positive
        6. limit the positive sample's center in gt

        Args:
            points (torch.Tensor): Points to be assigned, shape(n, 18).
            gt_rbboxes (torch.Tensor): Groundtruth polygons, shape (k, 8).
            gt_rbboxes_ignore (Tensor, optional): Ground truth polygons that
                are labelled as `ignored`, e.g., crowd boxes in COCO.
            gt_labels (Tensor, optional): Label of gt_bboxes, shape (k, ).

        Returns:
            :obj:`AssignResult`: The assign result.
        """
        num_points = points.shape[0]
        num_gts = gt_rbboxes.shape[0]

        if num_gts == 0 or num_points == 0:
            # If no truth assign everything to the background
            assigned_gt_inds = points.new_full((num_points, ),
                                               0,
                                               dtype=torch.long)
            if gt_labels is None:
                assigned_labels = None
            else:
                assigned_labels = points.new_full((num_points, ),
                                                  -1,
                                                  dtype=torch.long)
            return AssignResult(
                num_gts, assigned_gt_inds, None, labels=assigned_labels)

        points_xy = points[:, :2]
        points_stride = points[:, 2]
        points_lvl = torch.log2(points_stride).int()
        lvl_min, lvl_max = points_lvl.min(), points_lvl.max()

        assert gt_rbboxes.size(1) == 8, 'gt_rbboxes should be (N * 8)'
        gt_bboxes = self.get_horizontal_bboxes(gt_rbboxes)

        # assign gt rbox
        gt_bboxes_xy = (gt_bboxes[:, :2] + gt_bboxes[:, 2:]) / 2

        gt_bboxes_wh = (gt_bboxes[:, 2:] - gt_bboxes[:, :2]).clamp(min=1e-6)
        scale = self.scale
        gt_bboxes_lvl = ((torch.log2(gt_bboxes_wh[:, 0] / scale) +
                          torch.log2(gt_bboxes_wh[:, 1] / scale)) / 2).int()
        gt_bboxes_lvl = torch.clamp(gt_bboxes_lvl, min=lvl_min, max=lvl_max)

        # stores the assigned gt index of each point
        assigned_gt_inds = points.new_zeros((num_points, ), dtype=torch.long)
        # stores the assigned gt dist (to this point) of each point
        assigned_gt_dist = points.new_full((num_points, ), float('inf'))
        points_range = torch.arange(points.shape[0]).to(points.device)

        for idx in range(num_gts):
            gt_lvl = gt_bboxes_lvl[idx]
            # get the index of points in this level
            lvl_idx = gt_lvl == points_lvl
            points_index = points_range[lvl_idx]
            # get the points in this level
            lvl_points = points_xy[lvl_idx, :]
            # get the center point of gt
            gt_point = gt_bboxes_xy[[idx], :]
            # get width and height of gt
            gt_wh = gt_bboxes_wh[[idx], :]
            # compute the distance between gt center and
            #   all points in this level
            points_gt_dist = ((lvl_points - gt_point) / gt_wh).norm(dim=1)
            # find the nearest k points to gt center in this level
            min_dist, min_dist_index = torch.topk(
                points_gt_dist, self.pos_num, largest=False)
            # the index of nearest k points to gt center in this level
            min_dist_points_index = points_index[min_dist_index]

            # The less_than_recorded_index stores the index
            #   of min_dist that is less then the assigned_gt_dist. Where
            #   assigned_gt_dist stores the dist from previous assigned gt
            #   (if exist) to each point.
            less_than_recorded_index = min_dist < assigned_gt_dist[
                min_dist_points_index]
            # The min_dist_points_index stores the index of points satisfy:
            #   (1) it is k nearest to current gt center in this level.
            #   (2) it is closer to current gt center than other gt center.
            min_dist_points_index = min_dist_points_index[
                less_than_recorded_index]
            # assign the result
            assigned_gt_inds[min_dist_points_index] = idx + 1
            assigned_gt_dist[min_dist_points_index] = min_dist[
                less_than_recorded_index]

        if gt_labels is not None:
            assigned_labels = assigned_gt_inds.new_full((num_points, ),
                                                        -1,
                                                        dtype=torch.long)
            pos_inds = torch.nonzero(
                assigned_gt_inds > 0, as_tuple=False).squeeze()
            if pos_inds.numel() > 0:
                assigned_labels[pos_inds] = gt_labels[
                    assigned_gt_inds[pos_inds] - 1]
        else:
            assigned_labels = None

        return AssignResult(
            num_gts, assigned_gt_inds, None, labels=assigned_labels)
# Out:
# Overwriting /kaggle/working/mmrotate/mmrotate/core/bbox/assigners/convex_assigner.py

# %%
# %%writefile configs/sasm_reppoints/sasm_reppoints_r50_fpn_1x_sccos.py
_base_ = ['../rotated_reppoints/rotated_reppoints_r50_fpn_1x_dota_oc.py']


angle_version = 'le135'
model = dict(
    bbox_head=dict(
        type='SAMRepPointsHead',
        num_classes=1,
        loss_bbox_init=dict(type='BCConvexGIoULoss', loss_weight=0.375)),

    # training and testing settings
    train_cfg=dict(
        refine=dict(
            _delete_=True,
            assigner=dict(type='SASAssigner', topk=9),
            allowed_border=-1,
            pos_weight=-1,
            debug=False)))
dataset_type = 'DOTADataset'
# data_root = '/kaggle/working/sccos_dota/'
data_root = '/kaggle/input/sccos-dota/sccos_dota/'
classes = ('ship',)  # Explicitly define classes
img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53],
    std=[58.395, 57.12, 57.375],
    to_rgb=True)
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(type='RResize', img_scale=(1024, 1024)),
    dict(
        type='RRandomFlip',
        flip_ratio=[0.25, 0.25, 0.25],
        direction=['horizontal', 'vertical', 'diagonal'],
        version='le135'),
    dict(type='Normalize', **img_norm_cfg),
    dict(type='Pad', size_divisor=32),
    dict(type='DefaultFormatBundle'),
    dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
]
test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        img_scale=(1024, 1024),
        flip=False,
        transforms=[
            dict(type='RResize'),
            dict(type='Normalize', **img_norm_cfg),
            dict(type='Pad', size_divisor=32),
            dict(type='DefaultFormatBundle'),
            dict(type='Collect', keys=['img'])
        ])
]
data = dict(
    samples_per_gpu=4,
    workers_per_gpu=2,
    train=dict(
        type=dataset_type,
        ann_file=data_root + 'train/labels/',
        img_prefix=data_root + 'train/images/',
        pipeline=train_pipeline,
        version='le135',
        classes=('ship',)),
    val=dict(
        type=dataset_type,
        ann_file=data_root + 'val/labels/',
        img_prefix=data_root + 'val/images/',
        pipeline=test_pipeline,
        version='le135',
        classes=('ship',)),
    test=dict(
        type=dataset_type,
        ann_file=data_root + 'test/labels/',
        img_prefix=data_root + 'test/images/',
        pipeline=test_pipeline,
        version='le135',
        classes=('ship',)))
evaluation = dict(interval=1, metric='mAP', save_best='mAP') # Add save_best here
lr_config = dict(
    policy='step',
    warmup='linear',
    warmup_iters=1000,
    warmup_ratio=0.3333333333333333,
    step=[8, 11])
runner = dict(type='EpochBasedRunner', max_epochs=25)
checkpoint_config = dict(interval=1) # Keep interval for saving
log_config = dict(
    interval=100,
    hooks=[
        dict(type='TextLoggerHook'),
        dict(type='WandbLoggerHook',
             init_kwargs=dict(
                 project='SOTA',
                 name='sasm_reppoints_train'),
             interval=100)
    ])
# Out:
# Writing configs/sasm_reppoints/sasm_reppoints_r50_fpn_1x_sccos.py

# %%
# %cd /kaggle/working/mmrotate
# !python tools/analysis_tools/get_flops.py configs/sasm_reppoints/sasm_reppoints_r50_fpn_1x_sccos.py
# Out:
# /kaggle/working/mmrotate
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# RotatedRepPoints(
#   35.424 M, 96.777% Params, 194.241 GFLOPs, 100.000% FLOPs,
#   (backbone): ResNet(
#     23.283 M, 63.608% Params, 86.095 GFLOPs, 44.324% FLOPs,
#     (conv1): Conv2d(0.0 M, 0.000% Params, 2.466 GFLOPs, 1.270% FLOPs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(0.0 M, 0.000% Params, 0.034 GFLOPs, 0.017% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(0.0 M, 0.000% Params, 0.017 GFLOPs, 0.009% FLOPs, inplace=True)
#     (maxpool): MaxPool2d(0.0 M, 0.000% Params, 0.017 GFLOPs, 0.009% FLOPs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       0.0 M, 0.000% Params, 14.219 GFLOPs, 7.320% FLOPs,
#       (0): Bottleneck(
#         0.0 M, 0.000% Params, 4.941 GFLOPs, 2.544% FLOPs,
#         (conv1): Conv2d(0.0 M, 0.000% Params, 0.268 GFLOPs, 0.138% FLOPs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.000% Params, 0.008 GFLOPs, 0.004% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.0 M, 0.000% Params, 2.416 GFLOPs, 1.244% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.000% Params, 0.008 GFLOPs, 0.004% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.0 M, 0.000% Params, 1.074 GFLOPs, 0.553% FLOPs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.0 M, 0.000% Params, 0.034 GFLOPs, 0.017% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.025 GFLOPs, 0.013% FLOPs, inplace=True)
#         (downsample): Sequential(
#           0.0 M, 0.000% Params, 1.107 GFLOPs, 0.570% FLOPs,
#           (0): Conv2d(0.0 M, 0.000% Params, 1.074 GFLOPs, 0.553% FLOPs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(0.0 M, 0.000% Params, 0.034 GFLOPs, 0.017% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         0.0 M, 0.000% Params, 4.639 GFLOPs, 2.388% FLOPs,
#         (conv1): Conv2d(0.0 M, 0.000% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.000% Params, 0.008 GFLOPs, 0.004% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.0 M, 0.000% Params, 2.416 GFLOPs, 1.244% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.000% Params, 0.008 GFLOPs, 0.004% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.0 M, 0.000% Params, 1.074 GFLOPs, 0.553% FLOPs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.0 M, 0.000% Params, 0.034 GFLOPs, 0.017% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.025 GFLOPs, 0.013% FLOPs, inplace=True)
#       )
#       (2): Bottleneck(
#         0.0 M, 0.000% Params, 4.639 GFLOPs, 2.388% FLOPs,
#         (conv1): Conv2d(0.0 M, 0.000% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.000% Params, 0.008 GFLOPs, 0.004% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.0 M, 0.000% Params, 2.416 GFLOPs, 1.244% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.000% Params, 0.008 GFLOPs, 0.004% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.0 M, 0.000% Params, 1.074 GFLOPs, 0.553% FLOPs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.0 M, 0.000% Params, 0.034 GFLOPs, 0.017% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.025 GFLOPs, 0.013% FLOPs, inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       1.22 M, 3.332% Params, 21.661 GFLOPs, 11.152% FLOPs,
#       (0): Bottleneck(
#         0.379 M, 1.036% Params, 7.858 GFLOPs, 4.046% FLOPs,
#         (conv1): Conv2d(0.033 M, 0.090% Params, 2.147 GFLOPs, 1.106% FLOPs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.001% Params, 0.017 GFLOPs, 0.009% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.147 M, 0.403% Params, 2.416 GFLOPs, 1.244% FLOPs, 128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.001 M, 0.003% Params, 0.017 GFLOPs, 0.009% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.019 GFLOPs, 0.010% FLOPs, inplace=True)
#         (downsample): Sequential(
#           0.132 M, 0.361% Params, 2.164 GFLOPs, 1.114% FLOPs,
#           (0): Conv2d(0.131 M, 0.358% Params, 2.147 GFLOPs, 1.106% FLOPs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(0.001 M, 0.003% Params, 0.017 GFLOPs, 0.009% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         0.28 M, 0.765% Params, 4.601 GFLOPs, 2.369% FLOPs,
#         (conv1): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.147 M, 0.403% Params, 2.416 GFLOPs, 1.244% FLOPs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.001 M, 0.003% Params, 0.017 GFLOPs, 0.009% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.013 GFLOPs, 0.006% FLOPs, inplace=True)
#       )
#       (2): Bottleneck(
#         0.28 M, 0.765% Params, 4.601 GFLOPs, 2.369% FLOPs,
#         (conv1): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.147 M, 0.403% Params, 2.416 GFLOPs, 1.244% FLOPs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.001 M, 0.003% Params, 0.017 GFLOPs, 0.009% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.013 GFLOPs, 0.006% FLOPs, inplace=True)
#       )
#       (3): Bottleneck(
#         0.28 M, 0.765% Params, 4.601 GFLOPs, 2.369% FLOPs,
#         (conv1): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.147 M, 0.403% Params, 2.416 GFLOPs, 1.244% FLOPs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.0 M, 0.001% Params, 0.004 GFLOPs, 0.002% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.066 M, 0.179% Params, 1.074 GFLOPs, 0.553% FLOPs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.001 M, 0.003% Params, 0.017 GFLOPs, 0.009% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.013 GFLOPs, 0.006% FLOPs, inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       7.098 M, 19.393% Params, 30.733 GFLOPs, 15.822% FLOPs,
#       (0): Bottleneck(
#         1.512 M, 4.132% Params, 7.821 GFLOPs, 4.027% FLOPs,
#         (conv1): Conv2d(0.131 M, 0.358% Params, 2.147 GFLOPs, 1.106% FLOPs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.001% Params, 0.008 GFLOPs, 0.004% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.009 GFLOPs, 0.005% FLOPs, inplace=True)
#         (downsample): Sequential(
#           0.526 M, 1.438% Params, 2.156 GFLOPs, 1.110% FLOPs,
#           (0): Conv2d(0.524 M, 1.432% Params, 2.147 GFLOPs, 1.106% FLOPs, 512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         1.117 M, 3.052% Params, 4.582 GFLOPs, 2.359% FLOPs,
#         (conv1): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#       (2): Bottleneck(
#         1.117 M, 3.052% Params, 4.582 GFLOPs, 2.359% FLOPs,
#         (conv1): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#       (3): Bottleneck(
#         1.117 M, 3.052% Params, 4.582 GFLOPs, 2.359% FLOPs,
#         (conv1): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#       (4): Bottleneck(
#         1.117 M, 3.052% Params, 4.582 GFLOPs, 2.359% FLOPs,
#         (conv1): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#       (5): Bottleneck(
#         1.117 M, 3.052% Params, 4.582 GFLOPs, 2.359% FLOPs,
#         (conv1): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.002 M, 0.006% Params, 0.008 GFLOPs, 0.004% FLOPs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       14.965 M, 40.883% Params, 16.949 GFLOPs, 8.726% FLOPs,
#       (0): Bottleneck(
#         6.04 M, 16.500% Params, 7.803 GFLOPs, 4.017% FLOPs,
#         (conv1): Conv2d(0.524 M, 1.432% Params, 2.147 GFLOPs, 1.106% FLOPs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.003% Params, 0.004 GFLOPs, 0.002% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2.359 M, 6.446% Params, 2.416 GFLOPs, 1.244% FLOPs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.003% Params, 0.001 GFLOPs, 0.001% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1.049 M, 2.865% Params, 1.074 GFLOPs, 0.553% FLOPs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.004 M, 0.011% Params, 0.004 GFLOPs, 0.002% FLOPs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.005 GFLOPs, 0.002% FLOPs, inplace=True)
#         (downsample): Sequential(
#           2.101 M, 5.741% Params, 2.152 GFLOPs, 1.108% FLOPs,
#           (0): Conv2d(2.097 M, 5.729% Params, 2.147 GFLOPs, 1.106% FLOPs, 1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(0.004 M, 0.011% Params, 0.004 GFLOPs, 0.002% FLOPs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         4.463 M, 12.192% Params, 4.573 GFLOPs, 2.354% FLOPs,
#         (conv1): Conv2d(1.049 M, 2.865% Params, 1.074 GFLOPs, 0.553% FLOPs, 2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.003% Params, 0.001 GFLOPs, 0.001% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2.359 M, 6.446% Params, 2.416 GFLOPs, 1.244% FLOPs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.003% Params, 0.001 GFLOPs, 0.001% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1.049 M, 2.865% Params, 1.074 GFLOPs, 0.553% FLOPs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.004 M, 0.011% Params, 0.004 GFLOPs, 0.002% FLOPs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.003 GFLOPs, 0.002% FLOPs, inplace=True)
#       )
#       (2): Bottleneck(
#         4.463 M, 12.192% Params, 4.573 GFLOPs, 2.354% FLOPs,
#         (conv1): Conv2d(1.049 M, 2.865% Params, 1.074 GFLOPs, 0.553% FLOPs, 2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(0.001 M, 0.003% Params, 0.001 GFLOPs, 0.001% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(2.359 M, 6.446% Params, 2.416 GFLOPs, 1.244% FLOPs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(0.001 M, 0.003% Params, 0.001 GFLOPs, 0.001% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1.049 M, 2.865% Params, 1.074 GFLOPs, 0.553% FLOPs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(0.004 M, 0.011% Params, 0.004 GFLOPs, 0.002% FLOPs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(0.0 M, 0.000% Params, 0.003 GFLOPs, 0.002% FLOPs, inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
#   (neck): FPN(
#     7.999 M, 21.854% Params, 17.71 GFLOPs, 9.117% FLOPs,
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         0.132 M, 0.359% Params, 2.156 GFLOPs, 1.110% FLOPs,
#         (conv): Conv2d(0.131 M, 0.358% Params, 2.147 GFLOPs, 1.106% FLOPs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.008 GFLOPs, 0.004% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#       (1): ConvModule(
#         0.263 M, 0.718% Params, 1.076 GFLOPs, 0.554% FLOPs,
#         (conv): Conv2d(0.262 M, 0.716% Params, 1.074 GFLOPs, 0.553% FLOPs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#       (2): ConvModule(
#         0.525 M, 1.434% Params, 0.537 GFLOPs, 0.277% FLOPs,
#         (conv): Conv2d(0.524 M, 1.432% Params, 0.537 GFLOPs, 0.276% FLOPs, 2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.001 GFLOPs, 0.000% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0): ConvModule(
#         0.59 M, 1.613% Params, 9.672 GFLOPs, 4.979% FLOPs,
#         (conv): Conv2d(0.59 M, 1.611% Params, 9.664 GFLOPs, 4.975% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.008 GFLOPs, 0.004% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#       (1): ConvModule(
#         0.59 M, 1.613% Params, 2.418 GFLOPs, 1.245% FLOPs,
#         (conv): Conv2d(0.59 M, 1.611% Params, 2.416 GFLOPs, 1.244% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.002 GFLOPs, 0.001% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#       (2): ConvModule(
#         0.59 M, 1.613% Params, 0.605 GFLOPs, 0.311% FLOPs,
#         (conv): Conv2d(0.59 M, 1.611% Params, 0.604 GFLOPs, 0.311% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.001 GFLOPs, 0.000% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#       (3): ConvModule(
#         4.719 M, 12.893% Params, 1.208 GFLOPs, 0.622% FLOPs,
#         (conv): Conv2d(4.719 M, 12.891% Params, 1.208 GFLOPs, 0.622% FLOPs, 2048, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.0 GFLOPs, 0.000% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#       (4): ConvModule(
#         0.59 M, 1.613% Params, 0.038 GFLOPs, 0.019% FLOPs,
#         (conv): Conv2d(0.59 M, 1.611% Params, 0.038 GFLOPs, 0.019% FLOPs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.0 GFLOPs, 0.000% FLOPs, 32, 256, eps=1e-05, affine=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (bbox_head): SAMRepPointsHead(
#     4.142 M, 11.315% Params, 90.437 GFLOPs, 46.559% FLOPs,
#     (loss_cls): FocalLoss(0.0 M, 0.000% Params, 0.0 GFLOPs, 0.000% FLOPs, )
#     (loss_bbox_init): BCConvexGIoULoss(0.0 M, 0.000% Params, 0.0 GFLOPs, 0.000% FLOPs, )
#     (loss_bbox_refine): ConvexGIoULoss(0.0 M, 0.000% Params, 0.0 GFLOPs, 0.000% FLOPs, )
#     (relu): ReLU(0.0 M, 0.000% Params, 0.017 GFLOPs, 0.009% FLOPs, inplace=True)
#     (cls_convs): ModuleList(
#       (0-2): 3 x ConvModule(
#         0.59 M, 1.613% Params, 12.889 GFLOPs, 6.636% FLOPs,
#         (conv): Conv2d(0.59 M, 1.611% Params, 12.872 GFLOPs, 6.627% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.011 GFLOPs, 0.006% FLOPs, 32, 256, eps=1e-05, affine=True)
#         (activate): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#     )
#     (reg_convs): ModuleList(
#       (0-2): 3 x ConvModule(
#         0.59 M, 1.613% Params, 12.889 GFLOPs, 6.636% FLOPs,
#         (conv): Conv2d(0.59 M, 1.611% Params, 12.872 GFLOPs, 6.627% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (gn): GroupNorm(0.001 M, 0.001% Params, 0.011 GFLOPs, 0.006% FLOPs, 32, 256, eps=1e-05, affine=True)
#         (activate): ReLU(0.0 M, 0.000% Params, 0.006 GFLOPs, 0.003% FLOPs, inplace=True)
#       )
#     )
#     (reppoints_cls_conv): DeformConv2d(in_channels=256,
#     out_channels=256,
#     kernel_size=(3, 3),
#     stride=(1, 1),
#     padding=(1, 1),
#     dilation=(1, 1),
#     groups=1,
#     deform_groups=1,
#     bias=False)
#     (reppoints_cls_out): Conv2d(0.0 M, 0.001% Params, 0.006 GFLOPs, 0.003% FLOPs, 256, 1, kernel_size=(1, 1), stride=(1, 1))
#     (reppoints_pts_init_conv): Conv2d(0.59 M, 1.612% Params, 12.878 GFLOPs, 6.630% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (reppoints_pts_init_out): Conv2d(0.005 M, 0.013% Params, 0.101 GFLOPs, 0.052% FLOPs, 256, 18, kernel_size=(1, 1), stride=(1, 1))
#     (reppoints_pts_refine_conv): DeformConv2d(in_channels=256,
#     out_channels=256,
#     kernel_size=(3, 3),
#     stride=(1, 1),
#     padding=(1, 1),
#     dilation=(1, 1),
#     groups=1,
#     deform_groups=1,
#     bias=False)
#     (reppoints_pts_refine_out): Conv2d(0.005 M, 0.013% Params, 0.101 GFLOPs, 0.052% FLOPs, 256, 18, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'reppoints_cls_out', 'std': 0.01, 'bias_prob': 0.01}}
# )
# ==============================
# Input shape: (3, 1024, 1024)
# Flops: 194.24 GFLOPs
# Params: 36.6 M
# ==============================
# !!!Please be cautious if you use the results in papers. You may need to check if all ops are supported and verify that the flops computation is correct.

# %%
# Step 8: Train the Model
# %cd /kaggle/working/mmrotate
# !mkdir -p /kaggle/working/runs/sasm_reppoints


# !python tools/train.py \
    configs/sasm_reppoints/sasm_reppoints_r50_fpn_1x_sccos.py\
    --work-dir /kaggle/working/runs/sasm_reppoints \
    --gpus 1 \


print("Training completed.")
# Out:
# /kaggle/working/mmrotate
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /kaggle/working/mmrotate/mmrotate/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /kaggle/working/mmrotate/mmrotate/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# 2025-09-15 08:40:44,035 - mmrotate - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# CUDA available: True
# GPU 0: Tesla P100-PCIE-16GB
# CUDA_HOME: /usr/local/cuda
# NVCC: Cuda compilation tools, release 12.5, V12.5.82
# GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# PyTorch: 2.0.1+cu118
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2025.2-Product Build 20250620 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.15.2+cu118
# OpenCV: 4.11.0
# MMCV: 1.7.2
# MMCV Compiler: GCC 9.3
# MMCV CUDA Compiler: 11.8
# MMRotate: 0.3.4+7250f04
# ------------------------------------------------------------
#
# 2025-09-15 08:40:44,154 - mmrotate - INFO - Distributed training: False
# 2025-09-15 08:40:44,441 - mmrotate - INFO - Config:
# dataset_type = 'DOTADataset'
# data_root = '/kaggle/input/sccos-dota/sccos_dota/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='RResize', img_scale=(1024, 1024)),
#     dict(
#         type='RRandomFlip',
#         flip_ratio=[0.25, 0.25, 0.25],
#         direction=['horizontal', 'vertical', 'diagonal'],
#         version='le135'),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1024, 1024),
#         flip=False,
#         transforms=[
#             dict(type='RResize'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=4,
#     workers_per_gpu=2,
#     train=dict(
#         type='DOTADataset',
#         ann_file='/kaggle/input/sccos-dota/sccos_dota/train/labels/',
#         img_prefix='/kaggle/input/sccos-dota/sccos_dota/train/images/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='RResize', img_scale=(1024, 1024)),
#             dict(
#                 type='RRandomFlip',
#                 flip_ratio=[0.25, 0.25, 0.25],
#                 direction=['horizontal', 'vertical', 'diagonal'],
#                 version='le135'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         version='le135',
#         classes=('ship', )),
#     val=dict(
#         type='DOTADataset',
#         ann_file='/kaggle/input/sccos-dota/sccos_dota/val/labels/',
#         img_prefix='/kaggle/input/sccos-dota/sccos_dota/val/images/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1024, 1024),
#                 flip=False,
#                 transforms=[
#                     dict(type='RResize'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='DefaultFormatBundle'),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         version='le135',
#         classes=('ship', )),
#     test=dict(
#         type='DOTADataset',
#         ann_file='/kaggle/input/sccos-dota/sccos_dota/test/labels/',
#         img_prefix='/kaggle/input/sccos-dota/sccos_dota/test/images/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1024, 1024),
#                 flip=False,
#                 transforms=[
#                     dict(type='RResize'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='DefaultFormatBundle'),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         version='le135',
#         classes=('ship', )))
# evaluation = dict(interval=1, metric='mAP', save_best='mAP')
# optimizer = dict(type='SGD', lr=0.008, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=dict(max_norm=35, norm_type=2))
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=1000,
#     warmup_ratio=0.3333333333333333,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=25)
# checkpoint_config = dict(interval=1)
# log_config = dict(
#     interval=100,
#     hooks=[
#         dict(type='TextLoggerHook'),
#         dict(
#             type='WandbLoggerHook',
#             init_kwargs=dict(project='SOTA', name='sasm_reppoints_train'),
#             interval=100)
#     ])
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# angle_version = 'le135'
# norm_cfg = dict(type='GN', num_groups=32, requires_grad=True)
# model = dict(
#     type='RotatedRepPoints',
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         zero_init_residual=False,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         start_level=1,
#         add_extra_convs='on_input',
#         num_outs=5,
#         norm_cfg=dict(type='GN', num_groups=32, requires_grad=True)),
#     bbox_head=dict(
#         type='SAMRepPointsHead',
#         num_classes=1,
#         in_channels=256,
#         feat_channels=256,
#         point_feat_channels=256,
#         stacked_convs=3,
#         num_points=9,
#         gradient_mul=0.3,
#         point_strides=[8, 16, 32, 64, 128],
#         point_base_scale=2,
#         norm_cfg=dict(type='GN', num_groups=32, requires_grad=True),
#         loss_cls=dict(
#             type='FocalLoss',
#             use_sigmoid=True,
#             gamma=2.0,
#             alpha=0.25,
#             loss_weight=1.0),
#         loss_bbox_init=dict(type='BCConvexGIoULoss', loss_weight=0.375),
#         loss_bbox_refine=dict(type='ConvexGIoULoss', loss_weight=1.0),
#         transform_method='rotrect',
#         use_reassign=False,
#         topk=6,
#         anti_factor=0.75),
#     train_cfg=dict(
#         init=dict(
#             assigner=dict(type='ConvexAssigner', scale=4, pos_num=1),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         refine=dict(
#             assigner=dict(type='SASAssigner', topk=9),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         nms_pre=2000,
#         min_bbox_size=0,
#         score_thr=0.05,
#         nms=dict(iou_thr=0.4),
#         max_per_img=2000))
# classes = ('ship', )
# work_dir = '/kaggle/working/runs/sasm_reppoints'
# auto_resume = False
# gpu_ids = range(0, 1)
#
# 2025-09-15 08:40:44,443 - mmrotate - INFO - Set random seed to 1513611994, deterministic: False
# 2025-09-15 08:40:44,865 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2025-09-15 08:40:44,865 - mmcv - INFO - load model from: torchvision://resnet50
# 2025-09-15 08:40:44,865 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 146MB/s]
# 2025-09-15 08:40:45,781 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2025-09-15 08:40:45,806 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2025-09-15 08:40:45,858 - mmcv - INFO - initialize SAMRepPointsHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'reppoints_cls_out', 'std': 0.01, 'bias_prob': 0.01}}
# 2025-09-15 08:40:45,892 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,892 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,892 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,892 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,892 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,893 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,894 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,895 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,896 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,897 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,898 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,899 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,900 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,901 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,902 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,903 - mmcv - INFO -
# neck.lateral_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.lateral_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,904 - mmcv - INFO -
# neck.fpn_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 2048, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.3.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.3.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.4.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# neck.fpn_convs.4.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,905 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reppoints_cls_conv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,906 - mmcv - INFO -
# bbox_head.reppoints_cls_out.weight - torch.Size([1, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_cls_out.bias - torch.Size([1]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_init_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_init_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_init_out.weight - torch.Size([18, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_init_out.bias - torch.Size([18]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_refine_conv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of RotatedRepPoints
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_refine_out.weight - torch.Size([18, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:40:45,907 - mmcv - INFO -
# bbox_head.reppoints_pts_refine_out.bias - torch.Size([18]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2025-09-15 08:41:27,531 - mmrotate - INFO - Start running, host: root@1ed818aafc31, work_dir: /kaggle/working/runs/sasm_reppoints
# 2025-09-15 08:41:27,532 - mmrotate - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# 2025-09-15 08:41:27,532 - mmrotate - INFO - workflow: [('train', 1)], max: 25 epochs
# 2025-09-15 08:41:27,532 - mmrotate - INFO - Checkpoints will be saved to /kaggle/working/runs/sasm_reppoints by HardDiskBackend.
# wandb: Currently logged in as: tanish-jain140301 (tanish1403) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.20.1
# wandb: Run data is saved locally in /kaggle/working/mmrotate/wandb/run-20250915_084128-rsfa94hd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sasm_reppoints_train
# wandb: ⭐️ View project at https://wandb.ai/tanish1403/SOTA
# wandb: 🚀 View run at https://wandb.ai/tanish1403/SOTA/runs/rsfa94hd
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2025-09-15 08:43:01,588 - mmrotate - INFO - Epoch [1][100/928]	lr: 3.195e-03, eta: 5:53:26, time: 0.918, data_time: 0.043, memory: 6244, loss_cls: 0.8164, loss_pts_init: 5.9201, loss_pts_refine: 4.6227, loss: 11.3591, grad_norm: 8.7001
# ...
# 2025-09-15 12:23:52,016 - mmrotate - INFO - Now best checkpoint is saved as best_mAP_epoch_15.pth.
# 2025-09-15 12:23:52,017 - mmrotate - INFO - Best mAP is 0.7849 at 15 epoch.
# 2025-09-15 12:23:52,017 - mmrotate - INFO - Exp name: sasm_reppoints_r50_fpn_1x_sccos.py
# 2025-09-15 12:23:52,018 - mmrotate - INFO - Epoch(val) [15][464]	mAP: 0.7849
# 2025-09-15 12:25:24,533 - mmrotate - INFO - Epoch [16][100/928]	lr: 8.000e-05, eta: 2:14:10, time: 0.925, data_time: 0.043, memory: 6245, loss_cls: 0.1490, loss_pts_init: 1.7192, loss_pts_refine: 1.4570, loss: 3.3252, grad_norm: 3.9924
# 2025-09-15 12:26:54,666 - mmrotate - INFO - Epoch [16][200/928]	lr: 8.000e-05, eta: 2:12:44, time: 0.901, data_time: 0.020, memory: 6245, loss_cls: 0.1475, loss_pts_init: 1.9979, loss_pts_refine: 1.4548, loss: 3.6002, grad_norm: 3.9760
# 2025-09-15 12:28:24,985 - mmrotate - INFO - Epoch [16][300/928]	lr: 8.000e-05, eta: 2:11:18, time: 0.903, data_time: 0.019, memory: 6245, loss_cls: 0.1482, loss_pts_init: 1.8178, loss_pts_refine: 1.4667, loss: 3.4327, grad_norm: 3.9376
# 2025-09-15 12:29:54,874 - mmrotate - INFO - Epoch [16][400/928]	lr: 8.000e-05, eta: 2:09:52, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1502, loss_pts_init: 1.8152, loss_pts_refine: 1.4897, loss: 3.4550, grad_norm: 4.0722
# 2025-09-15 12:31:25,080 - mmrotate - INFO - Epoch [16][500/928]	lr: 8.000e-05, eta: 2:08:25, time: 0.902, data_time: 0.019, memory: 6245, loss_cls: 0.1449, loss_pts_init: 1.7931, loss_pts_refine: 1.5206, loss: 3.4587, grad_norm: 3.7860
# 2025-09-15 12:32:55,017 - mmrotate - INFO - Epoch [16][600/928]	lr: 8.000e-05, eta: 2:06:59, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1440, loss_pts_init: 1.8021, loss_pts_refine: 1.4765, loss: 3.4227, grad_norm: 4.0259
# 2025-09-15 12:34:25,062 - mmrotate - INFO - Epoch [16][700/928]	lr: 8.000e-05, eta: 2:05:32, time: 0.900, data_time: 0.019, memory: 6245, loss_cls: 0.1531, loss_pts_init: 1.9281, loss_pts_refine: 1.5307, loss: 3.6119, grad_norm: 3.7879
# 2025-09-15 12:35:54,933 - mmrotate - INFO - Epoch [16][800/928]	lr: 8.000e-05, eta: 2:04:06, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1473, loss_pts_init: 1.7497, loss_pts_refine: 1.5120, loss: 3.4090, grad_norm: 4.0233
# 2025-09-15 12:37:25,170 - mmrotate - INFO - Epoch [16][900/928]	lr: 8.000e-05, eta: 2:02:39, time: 0.902, data_time: 0.019, memory: 6245, loss_cls: 0.1509, loss_pts_init: 1.8405, loss_pts_refine: 1.4897, loss: 3.4811, grad_norm: 4.2946
# 2025-09-15 12:37:50,401 - mmrotate - INFO - Saving checkpoint at 16 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 464/464, 11.6 task/s, elapsed: 40s, ETA:     0s/usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# 2025-09-15 12:38:39,892 - mmrotate - INFO -
# +-------+------+-------+--------+-------+
# | class | gts  | dets  | recall | ap    |
# +-------+------+-------+--------+-------+
# | ship  | 1744 | 15682 | 0.921  | 0.788 |
# +-------+------+-------+--------+-------+
# | mAP   |      |       |        | 0.788 |
# +-------+------+-------+--------+-------+
# 2025-09-15 12:38:40,040 - mmrotate - INFO - The previous best checkpoint /kaggle/working/runs/sasm_reppoints/best_mAP_epoch_15.pth was removed
# 2025-09-15 12:38:40,897 - mmrotate - INFO - Now best checkpoint is saved as best_mAP_epoch_16.pth.
# 2025-09-15 12:38:40,898 - mmrotate - INFO - Best mAP is 0.7882 at 16 epoch.
# 2025-09-15 12:38:40,898 - mmrotate - INFO - Exp name: sasm_reppoints_r50_fpn_1x_sccos.py
# 2025-09-15 12:38:40,899 - mmrotate - INFO - Epoch(val) [16][464]	mAP: 0.7882
# 2025-09-15 12:40:14,163 - mmrotate - INFO - Epoch [17][100/928]	lr: 8.000e-05, eta: 2:00:36, time: 0.932, data_time: 0.043, memory: 6245, loss_cls: 0.1508, loss_pts_init: 1.8608, loss_pts_refine: 1.5716, loss: 3.5831, grad_norm: 3.8069
# 2025-09-15 12:41:44,141 - mmrotate - INFO - Epoch [17][200/928]	lr: 8.000e-05, eta: 1:59:10, time: 0.900, data_time: 0.020, memory: 6245, loss_cls: 0.1469, loss_pts_init: 1.8301, loss_pts_refine: 1.4593, loss: 3.4362, grad_norm: 4.2020
# 2025-09-15 12:43:14,047 - mmrotate - INFO - Epoch [17][300/928]	lr: 8.000e-05, eta: 1:57:43, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1490, loss_pts_init: 1.7263, loss_pts_refine: 1.5220, loss: 3.3974, grad_norm: 3.9102
# 2025-09-15 12:44:44,003 - mmrotate - INFO - Epoch [17][400/928]	lr: 8.000e-05, eta: 1:56:17, time: 0.900, data_time: 0.020, memory: 6245, loss_cls: 0.1448, loss_pts_init: 1.8000, loss_pts_refine: 1.4905, loss: 3.4353, grad_norm: 3.9618
# 2025-09-15 12:46:13,858 - mmrotate - INFO - Epoch [17][500/928]	lr: 8.000e-05, eta: 1:54:50, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1518, loss_pts_init: 1.8370, loss_pts_refine: 1.4848, loss: 3.4735, grad_norm: 4.0610
# 2025-09-15 12:47:44,210 - mmrotate - INFO - Epoch [17][600/928]	lr: 8.000e-05, eta: 1:53:24, time: 0.904, data_time: 0.020, memory: 6245, loss_cls: 0.1565, loss_pts_init: 1.9252, loss_pts_refine: 1.5456, loss: 3.6273, grad_norm: 3.9792
# 2025-09-15 12:49:14,294 - mmrotate - INFO - Epoch [17][700/928]	lr: 8.000e-05, eta: 1:51:57, time: 0.901, data_time: 0.020, memory: 6245, loss_cls: 0.1404, loss_pts_init: 1.8522, loss_pts_refine: 1.4593, loss: 3.4519, grad_norm: 4.0298
# 2025-09-15 12:50:44,428 - mmrotate - INFO - Epoch [17][800/928]	lr: 8.000e-05, eta: 1:50:30, time: 0.901, data_time: 0.019, memory: 6245, loss_cls: 0.1433, loss_pts_init: 1.7531, loss_pts_refine: 1.4338, loss: 3.3302, grad_norm: 3.9400
# 2025-09-15 12:52:14,474 - mmrotate - INFO - Epoch [17][900/928]	lr: 8.000e-05, eta: 1:49:04, time: 0.900, data_time: 0.019, memory: 6245, loss_cls: 0.1540, loss_pts_init: 1.8525, loss_pts_refine: 1.4732, loss: 3.4797, grad_norm: 4.2658
# 2025-09-15 12:52:39,665 - mmrotate - INFO - Saving checkpoint at 17 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 464/464, 11.6 task/s, elapsed: 40s, ETA:     0s/usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# 2025-09-15 12:53:28,622 - mmrotate - INFO -
# +-------+------+-------+--------+-------+
# | class | gts  | dets  | recall | ap    |
# +-------+------+-------+--------+-------+
# | ship  | 1744 | 14573 | 0.922  | 0.787 |
# +-------+------+-------+--------+-------+
# | mAP   |      |       |        | 0.787 |
# +-------+------+-------+--------+-------+
# 2025-09-15 12:53:28,706 - mmrotate - INFO - Exp name: sasm_reppoints_r50_fpn_1x_sccos.py
# 2025-09-15 12:53:28,707 - mmrotate - INFO - Epoch(val) [17][464]	mAP: 0.7873
# 2025-09-15 12:55:01,329 - mmrotate - INFO - Epoch [18][100/928]	lr: 8.000e-05, eta: 1:47:02, time: 0.926, data_time: 0.044, memory: 6245, loss_cls: 0.1451, loss_pts_init: 1.9258, loss_pts_refine: 1.4935, loss: 3.5644, grad_norm: 4.0675
# 2025-09-15 12:56:31,035 - mmrotate - INFO - Epoch [18][200/928]	lr: 8.000e-05, eta: 1:45:35, time: 0.897, data_time: 0.018, memory: 6245, loss_cls: 0.1496, loss_pts_init: 1.7746, loss_pts_refine: 1.4690, loss: 3.3933, grad_norm: 4.0073
# 2025-09-15 12:58:00,977 - mmrotate - INFO - Epoch [18][300/928]	lr: 8.000e-05, eta: 1:44:09, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1495, loss_pts_init: 1.9221, loss_pts_refine: 1.5025, loss: 3.5741, grad_norm: 4.1582
# 2025-09-15 12:59:30,836 - mmrotate - INFO - Epoch [18][400/928]	lr: 8.000e-05, eta: 1:42:42, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1462, loss_pts_init: 1.8237, loss_pts_refine: 1.4079, loss: 3.3778, grad_norm: 4.0374
# 2025-09-15 13:01:00,732 - mmrotate - INFO - Epoch [18][500/928]	lr: 8.000e-05, eta: 1:41:15, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1492, loss_pts_init: 1.8410, loss_pts_refine: 1.4930, loss: 3.4832, grad_norm: 4.0681
# 2025-09-15 13:02:31,072 - mmrotate - INFO - Epoch [18][600/928]	lr: 8.000e-05, eta: 1:39:48, time: 0.903, data_time: 0.019, memory: 6245, loss_cls: 0.1415, loss_pts_init: 1.8703, loss_pts_refine: 1.5496, loss: 3.5614, grad_norm: 3.9426
# 2025-09-15 13:04:00,977 - mmrotate - INFO - Epoch [18][700/928]	lr: 8.000e-05, eta: 1:38:21, time: 0.899, data_time: 0.019, memory: 6245, loss_cls: 0.1473, loss_pts_init: 1.7200, loss_pts_refine: 1.5171, loss: 3.3845, grad_norm: 3.8597
# 2025-09-15 13:05:31,087 - mmrotate - INFO - Epoch [18][800/928]	lr: 8.000e-05, eta: 1:36:55, time: 0.901, data_time: 0.020, memory: 6245, loss_cls: 0.1528, loss_pts_init: 1.9514, loss_pts_refine: 1.5187, loss: 3.6228, grad_norm: 3.9558
# 2025-09-15 13:07:01,092 - mmrotate - INFO - Epoch [18][900/928]	lr: 8.000e-05, eta: 1:35:28, time: 0.900, data_time: 0.019, memory: 6245, loss_cls: 0.1477, loss_pts_init: 1.7873, loss_pts_refine: 1.5466, loss: 3.4815, grad_norm: 4.0811
# 2025-09-15 13:07:26,322 - mmrotate - INFO - Saving checkpoint at 18 epochs
# [>>>>>>>>>>>>>>>>>            ] 284/464, 11.6 task/s, elapsed: 25s, ETA:    16sTraceback (most recent call last):
#   File "/kaggle/working/mmrotate/tools/train.py", line 194, in <module>
#     main()
#   File "/kaggle/working/mmrotate/tools/train.py", line 183, in main
#     train_detector(
#   File "/kaggle/working/mmrotate/mmrotate/apis/train.py", line 144, in train_detector
#     runner.run(data_loaders, cfg.workflow)
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/runner/epoch_based_runner.py", line 136, in run
#     epoch_runner(data_loaders[i], **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/runner/epoch_based_runner.py", line 58, in train
#     self.call_hook('after_train_epoch')
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/runner/base_runner.py", line 317, in call_hook
#     getattr(hook, fn_name)(self)
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/runner/hooks/evaluation.py", line 271, in after_train_epoch
#     self._do_evaluate(runner)
#   File "/usr/local/lib/python3.11/dist-packages/mmdet/core/evaluation/eval_hooks.py", line 60, in _do_evaluate
#     results = single_gpu_test(runner.model, self.dataloader, show=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmdet/apis/test.py", line 29, in single_gpu_test
#     result = model(return_loss=False, rescale=True, **data)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/parallel/data_parallel.py", line 51, in forward
#     return super().forward(*inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/parallel/data_parallel.py", line 169, in forward
#     return self.module(*inputs[0], **kwargs[0])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/runner/fp16_utils.py", line 119, in new_func
#     return old_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmdet/models/detectors/base.py", line 174, in forward
#     return self.forward_test(img, img_metas, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmdet/models/detectors/base.py", line 147, in forward_test
#     return self.simple_test(imgs[0], img_metas[0], **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/mmrotate/mmrotate/models/detectors/single_stage.py", line 101, in simple_test
#     bbox_list = self.bbox_head.get_bboxes(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mmcv/runner/fp16_utils.py", line 208, in new_func
#     return old_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/mmrotate/mmrotate/models/dense_heads/sam_reppoints_head.py", line 734, in get_bboxes
#     results = self._get_bboxes_single(cls_score_list, point_pred_list,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/mmrotate/mmrotate/models/dense_heads/sam_reppoints_head.py", line 828, in _get_bboxes_single
#     mlvl_bboxes[..., :4] /= mlvl_bboxes[..., :4].new_tensor(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: CUDA error: an illegal memory access was encountered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# wandb:
# wandb: 🚀 View run sasm_reppoints_train at: https://wandb.ai/tanish1403/SOTA/runs/rsfa94hd
# wandb: Find logs at: wandb/run-20250915_084128-rsfa94hd/logs
# Training completed.

# %%
# Test FIRNet (uncomment to run)
import os
import glob

# %cd /kaggle/working/mmrotate

# Step 1: Find the best checkpoint file automatically
checkpoint_dir = '/kaggle/working/runs/sasm_reppoints'
best_checkpoint_path = None
# Search for the best checkpoint file
for filename in glob.glob(os.path.join(checkpoint_dir, 'best_mAP_*.pth')):
    best_checkpoint_path = filename
    break  # Take the first one found

if best_checkpoint_path:
    print(f"Found best checkpoint: {best_checkpoint_path}")
    
    # Step 2: Run the test command with the found checkpoint
    # !mkdir -p /kaggle/working/runs/sasm_reppoints_test
    # !python tools/test.py \
        configs/sasm_reppoints/sasm_reppoints_r50_fpn_1x_sccos.py \
        {best_checkpoint_path} \
        --eval mAP \
        --out /kaggle/working/runs/sasm_reppoints_test/results.pkl \
        --show-dir /kaggle/working/runs/sasm_reppoints_test/vis
    
    print("FIRNet testing completed. Results saved.")
else:
    print(f"Error: No best checkpoint found in {checkpoint_dir}. Please ensure training was successful.")
# Out:
# /kaggle/working/mmrotate
# Found best checkpoint: /kaggle/working/runs/sasm_reppoints/best_mAP_epoch_16.pth
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /kaggle/working/mmrotate/mmrotate/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /kaggle/working/mmrotate/mmrotate/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# load checkpoint from local path: /kaggle/working/runs/sasm_reppoints/best_mAP_epoch_16.pth
# [                                                  ] 0/464, elapsed: 0s, ETA:/usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 464/464, 3.3 task/s, elapsed: 139s, ETA:     0s
# writing results to /kaggle/working/runs/sasm_reppoints_test/results.pkl
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
#
# +-------+------+-------+--------+-------+
# | class | gts  | dets  | recall | ap    |
# +-------+------+-------+--------+-------+
# | ship  | 2140 | 18513 | 0.858  | 0.715 |
# +-------+------+-------+--------+-------+
# | mAP   |      |       |        | 0.715 |
# +-------+------+-------+--------+-------+
# {'mAP': 0.7149640917778015}
# FIRNet testing completed. Results saved.
